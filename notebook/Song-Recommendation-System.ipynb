# %% [markdown]
# # Taylor Swift Song Recommendation System

# %%
import re
import time
import nltk
import base64
import random
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from sklearn.pipeline import Pipeline
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\varun\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\varun\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\varun\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %% [markdown]
# ### Required keys

# %%
# Client ID and Client Secret from your Spotify Developer Dashboard and Genius API
client_id="0c64bcdd0c2a4358bc87d3bcc131ead0"
client_secret="21dbcb4e2819426f84774f107e3afd30"
genius_id = "0_wLcdeAud59txTzl5JFX3sviHZ1AJ_eXDkGgckvKwCo1zXEVk-b_wgKoIgFGPWA"
genius_secret = "_3AifiMFK0O66f0OpsXR0XTfHTBS6oyMXbc2VjHpsid2WYSS79MC88-0VVlOdWw5UgHhe3BULyzufwc9dmuTTA"
genius_token = "2rjwQEla2H09EoEfojKm1sB0naqVQGt0m1ZopxDsg25dXBAzD7wMadTrmawElSOt"

# %% [markdown]
# ### Data Collection

# %%
# ----------------------------------------------
# 1. Spotify API - Get All Taylor Swift's Tracks
# ----------------------------------------------

# Spotify API credentials
spotify_client_id = client_id
spotify_client_secret = client_secret

# Function to get Spotify access token
def get_spotify_token(client_id, client_secret):
    client_creds = f"{client_id}:{client_secret}"
    client_creds_b64 = base64.b64encode(client_creds.encode())

    token_url = "https://accounts.spotify.com/api/token"
    headers = {
        "Authorization": f"Basic {client_creds_b64.decode()}"
    }
    data = {
        "grant_type": "client_credentials"
    }

    response = requests.post(token_url, headers=headers, data=data)
    return response.json().get('access_token')

# Get Spotify access token
spotify_token = get_spotify_token(spotify_client_id, spotify_client_secret)

# Function to get Taylor Swift's Artist ID
def get_artist_id(artist_name):
    search_url = "https://api.spotify.com/v1/search"
    headers = {
        "Authorization": f"Bearer {spotify_token}"
    }
    params = {
        "q": artist_name,
        "type": "artist",
        "limit": 1
    }

    response = requests.get(search_url, headers=headers, params=params)
    artist_info = response.json()
    return artist_info['artists']['items'][0]['id']

# Get Taylor Swift's artist ID
artist_id = get_artist_id("Taylor Swift")

# Function to get all tracks by an artist
def get_all_tracks(artist_id):
    albums_url = f"https://api.spotify.com/v1/artists/{artist_id}/albums"
    headers = {
        "Authorization": f"Bearer {spotify_token}"
    }
    params = {
        "include_groups": "album,single",
        "limit": 50
    }

    response = requests.get(albums_url, headers=headers, params=params)
    albums = response.json()
    tracks = []

    for album in albums['items']:
        album_id = album['id']
        album_name = album['name']
        
        # Get tracks for each album
        tracks_url = f"https://api.spotify.com/v1/albums/{album_id}/tracks"
        response = requests.get(tracks_url, headers=headers)
        album_tracks = response.json()
        
        for track in album_tracks['items']:
            tracks.append({
                'track_name': track['name'],
                'album_name': album_name,
                'track_id': track['id'],
                'duration_ms': track['duration_ms']
            })
    
    return tracks

# Fetch all tracks by Taylor Swift
tracks = get_all_tracks(artist_id)

# -------------------------------------------------
# 2. Spotify Audio Features API - Get Song Mood Data
# -------------------------------------------------

# Function to get audio features for a track
def get_audio_features(track_ids):
    features_url = "https://api.spotify.com/v1/audio-features"
    headers = {
        "Authorization": f"Bearer {spotify_token}"
    }
    
    audio_features = []
    # Fetch in batches of up to 100 track_ids (Spotify API limit)
    for i in range(0, len(track_ids), 100):
        ids_batch = ",".join(track_ids[i:i+100])
        response = requests.get(features_url, headers=headers, params={'ids': ids_batch})
        
        if response.status_code == 200:
            features = response.json()['audio_features']
            if features:
                audio_features += features
            else:
                print(f"No features found for batch {i // 100 + 1}.")
        else:
            print(f"Error fetching features: {response.status_code} - {response.text}")
        
        # Sleep to avoid rate limits
        time.sleep(0.2)  # Spotify API allows 5 requests per second
    
    return audio_features

def get_audio_features_for_mood(track_id):
    features_url = f"https://api.spotify.com/v1/audio-features/{track_id}"
    headers = {
        "Authorization": f"Bearer {spotify_token}"
    }

    response = requests.get(features_url, headers=headers)
    if response.status_code == 200:
        return response.json()
    return None
    
# Function to predict mood based on audio features
def predict_mood(valence, energy):
    if valence > 0.8:
        return "Happy"
    elif valence < 0.35:
        return "Sad"
    elif energy > 0.7:
        return "Energetic"
    else:
        return "Calm"

# -------------------------------------------
# 3. Genius API - Get Lyrics for Each Track
# -------------------------------------------

# Function to search for lyrics on Genius
def get_lyrics(song_title, artist_name):
    base_url = "https://api.genius.com"
    headers = {
        "Authorization": f"Bearer {genius_token}"
    }
    
    search_url = base_url + "/search"
    params = {'q': f"{song_title} {artist_name}"}
    response = requests.get(search_url, headers=headers, params=params)
    
    if response.status_code != 200:
        return None  # No lyrics found
    
    search_results = response.json()
    if len(search_results['response']['hits']) == 0:
        return None
    
    # Get the URL of the first matching song on Genius
    song_url = search_results['response']['hits'][0]['result']['url']
    return song_url

# Function to extract lyrics from Genius song URL (using web scraping)
def extract_lyrics(lyrics_url):
    response = requests.get(lyrics_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Genius has a new structure for lyrics in <div class='Lyrics__Container'>
    lyrics = ""
    for div in soup.find_all("div", class_=re.compile("^Lyrics__Container")):
        for br in div.find_all("br"):
            br.replace_with("\n")  # Handle line breaks
        lyrics += div.get_text(separator="\n").strip()

    if not lyrics:
        return None
    
    return lyrics.strip()

# -----------------------------------------------------
# 4. Combine Track Data with Lyrics and Mood Prediction
# -----------------------------------------------------

tracks_with_lyrics_and_mood = []

for track in tracks:
    track_name = track['track_name']
    artist_name = "Taylor Swift"  # All tracks are by Taylor Swift
    
    # Fetch lyrics for each track
    print(f"Fetching lyrics for: {track_name}")
    lyrics_url = get_lyrics(track_name, artist_name)
    
    if lyrics_url:
        lyrics = extract_lyrics(lyrics_url)
        if lyrics:
            print(f"Lyrics found for '{track_name}'")
        else:
            print(f"Lyrics not available for '{track_name}'")
    else:
        lyrics = None
        print(f"No lyrics found for '{track_name}'")
    
    # Fetch audio features and predict mood
    audio_features = get_audio_features_for_mood(track['track_id'])
    if audio_features:
        valence = audio_features.get('valence', 0)
        energy = audio_features.get('energy', 0)
        mood = predict_mood(valence, energy)
    else:
        mood = "Unknown"
    
    # Append lyrics and mood to the track data
    track['lyrics'] = lyrics
    track['mood'] = mood
    tracks_with_lyrics_and_mood.append(track)
    
    # Be mindful of rate limits by adding delay
    time.sleep(1)

# Convert to DataFrame and save
df = pd.DataFrame(tracks_with_lyrics_and_mood)

# Get the list of track IDs
track_ids = df['track_id'].tolist()

# Fetch audio features
audio_features = get_audio_features(track_ids)

# Convert audio features into a DataFrame
audio_features_df = pd.DataFrame(audio_features)

# Merge the audio features with the original dataset based on 'track_id'
df = pd.merge(df, audio_features_df, left_on='track_id', right_on = 'id', how='left')

df.to_csv('taylor_swift_tracks_dataset.csv', index=False)
# Out:
# Fetching lyrics for: Fortnight (feat. Post Malone)
# Lyrics found for 'Fortnight (feat. Post Malone)'
# Fetching lyrics for: The Tortured Poets Department
# Lyrics found for 'The Tortured Poets Department'
# Fetching lyrics for: My Boy Only Breaks His Favorite Toys
# Lyrics found for 'My Boy Only Breaks His Favorite Toys'
# Fetching lyrics for: Down Bad
# Lyrics found for 'Down Bad'
# Fetching lyrics for: So Long, London
# Lyrics found for 'So Long, London'
# Fetching lyrics for: But Daddy I Love Him
# Lyrics found for 'But Daddy I Love Him'
# Fetching lyrics for: Fresh Out The Slammer
# Lyrics found for 'Fresh Out The Slammer'
# Fetching lyrics for: Florida!!! (feat. Florence + The Machine)
# Lyrics found for 'Florida!!! (feat. Florence + The Machine)'
# Fetching lyrics for: Guilty as Sin?
# Lyrics found for 'Guilty as Sin?'
# Fetching lyrics for: Who’s Afraid of Little Old Me?
# Lyrics found for 'Who’s Afraid of Little Old Me?'
# Fetching lyrics for: I Can Fix Him (No Really I Can)
# Lyrics found for 'I Can Fix Him (No Really I Can)'
# Fetching lyrics for: loml
# Lyrics found for 'loml'
# Fetching lyrics for: I Can Do It With a Broken Heart
# Lyrics found for 'I Can Do It With a Broken Heart'
# Fetching lyrics for: The Smallest Man Who Ever Lived
# Lyrics found for 'The Smallest Man Who Ever Lived'
# Fetching lyrics for: The Alchemy
# Lyrics found for 'The Alchemy'
# Fetching lyrics for: Clara Bow
# Lyrics found for 'Clara Bow'
# Fetching lyrics for: The Black Dog
# Lyrics found for 'The Black Dog'
# Fetching lyrics for: imgonnagetyouback
# Lyrics found for 'imgonnagetyouback'
# Fetching lyrics for: The Albatross
# Lyrics found for 'The Albatross'
# Fetching lyrics for: Chloe or Sam or Sophia or Marcus
# Lyrics found for 'Chloe or Sam or Sophia or Marcus'
# Fetching lyrics for: Fortnight (feat. Post Malone)
# Lyrics found for 'Fortnight (feat. Post Malone)'
# Fetching lyrics for: The Tortured Poets Department
# Lyrics found for 'The Tortured Poets Department'
# Fetching lyrics for: My Boy Only Breaks His Favorite Toys
# Lyrics found for 'My Boy Only Breaks His Favorite Toys'
# Fetching lyrics for: Down Bad
# Lyrics found for 'Down Bad'
# Fetching lyrics for: So Long, London
# Lyrics found for 'So Long, London'
# Fetching lyrics for: But Daddy I Love Him
# Lyrics found for 'But Daddy I Love Him'
# Fetching lyrics for: Fresh Out The Slammer
# Lyrics found for 'Fresh Out The Slammer'
# Fetching lyrics for: Florida!!! (feat. Florence + The Machine)
# Lyrics found for 'Florida!!! (feat. Florence + The Machine)'
# Fetching lyrics for: Guilty as Sin?
# Lyrics found for 'Guilty as Sin?'
# Fetching lyrics for: Who’s Afraid of Little Old Me?
# Lyrics found for 'Who’s Afraid of Little Old Me?'
# Fetching lyrics for: I Can Fix Him (No Really I Can)
# Lyrics found for 'I Can Fix Him (No Really I Can)'
# Fetching lyrics for: loml
# Lyrics found for 'loml'
# Fetching lyrics for: I Can Do It With a Broken Heart
# Lyrics found for 'I Can Do It With a Broken Heart'
# Fetching lyrics for: The Smallest Man Who Ever Lived
# Lyrics found for 'The Smallest Man Who Ever Lived'
# Fetching lyrics for: The Alchemy
# Lyrics found for 'The Alchemy'
# Fetching lyrics for: Clara Bow
# Lyrics found for 'Clara Bow'
# Fetching lyrics for: Welcome To New York (Taylor's Version)
# Lyrics found for 'Welcome To New York (Taylor's Version)'
# Fetching lyrics for: Blank Space (Taylor's Version)
# Lyrics found for 'Blank Space (Taylor's Version)'
# Fetching lyrics for: Style (Taylor's Version)
# Lyrics found for 'Style (Taylor's Version)'
# Fetching lyrics for: Out Of The Woods (Taylor's Version)
# Lyrics found for 'Out Of The Woods (Taylor's Version)'
# Fetching lyrics for: All You Had To Do Was Stay (Taylor's Version)
# Lyrics found for 'All You Had To Do Was Stay (Taylor's Version)'
# Fetching lyrics for: Shake It Off (Taylor's Version)
# Lyrics found for 'Shake It Off (Taylor's Version)'
# Fetching lyrics for: I Wish You Would (Taylor's Version)
# Lyrics found for 'I Wish You Would (Taylor's Version)'
# Fetching lyrics for: Bad Blood (Taylor's Version)
# Lyrics found for 'Bad Blood (Taylor's Version)'
# Fetching lyrics for: Wildest Dreams (Taylor's Version)
# Lyrics found for 'Wildest Dreams (Taylor's Version)'
# Fetching lyrics for: How You Get The Girl (Taylor's Version)
# Lyrics found for 'How You Get The Girl (Taylor's Version)'
# Fetching lyrics for: This Love (Taylor’s Version)
# Lyrics found for 'This Love (Taylor’s Version)'
# Fetching lyrics for: I Know Places (Taylor's Version)
# Lyrics found for 'I Know Places (Taylor's Version)'
# Fetching lyrics for: Clean (Taylor's Version)
# Lyrics found for 'Clean (Taylor's Version)'
# Fetching lyrics for: Wonderland (Taylor's Version)
# Lyrics found for 'Wonderland (Taylor's Version)'
# Fetching lyrics for: You Are In Love (Taylor's Version)
# Lyrics found for 'You Are In Love (Taylor's Version)'
# Fetching lyrics for: New Romantics (Taylor's Version)
# Lyrics found for 'New Romantics (Taylor's Version)'
# Fetching lyrics for: "Slut!" (Taylor's Version) (From The Vault)
# Lyrics found for '"Slut!" (Taylor's Version) (From The Vault)'
# Fetching lyrics for: Say Don't Go (Taylor's Version) (From The Vault)
# Lyrics found for 'Say Don't Go (Taylor's Version) (From The Vault)'
# Fetching lyrics for: Now That We Don't Talk (Taylor's Version) (From The Vault)
# Lyrics found for 'Now That We Don't Talk (Taylor's Version) (From The Vault)'
# Fetching lyrics for: Suburban Legends (Taylor's Version) (From The Vault)
# Lyrics found for 'Suburban Legends (Taylor's Version) (From The Vault)'
# Fetching lyrics for: Welcome To New York (Taylor's Version)
# Lyrics found for 'Welcome To New York (Taylor's Version)'
# Fetching lyrics for: Blank Space (Taylor's Version)
# Lyrics found for 'Blank Space (Taylor's Version)'
# Fetching lyrics for: Style (Taylor's Version)
# Lyrics found for 'Style (Taylor's Version)'
# Fetching lyrics for: Out Of The Woods (Taylor's Version)
# Lyrics found for 'Out Of The Woods (Taylor's Version)'
# Fetching lyrics for: All You Had To Do Was Stay (Taylor's Version)
# Lyrics found for 'All You Had To Do Was Stay (Taylor's Version)'
# Fetching lyrics for: Shake It Off (Taylor's Version)
# Lyrics found for 'Shake It Off (Taylor's Version)'
# Fetching lyrics for: I Wish You Would (Taylor's Version)
# Lyrics found for 'I Wish You Would (Taylor's Version)'
# Fetching lyrics for: Bad Blood (Taylor's Version)
# Lyrics found for 'Bad Blood (Taylor's Version)'
# Fetching lyrics for: Wildest Dreams (Taylor's Version)
# Lyrics found for 'Wildest Dreams (Taylor's Version)'
# Fetching lyrics for: How You Get The Girl (Taylor's Version)
# Lyrics found for 'How You Get The Girl (Taylor's Version)'
# Fetching lyrics for: This Love (Taylor’s Version)
# Lyrics found for 'This Love (Taylor’s Version)'
# Fetching lyrics for: I Know Places (Taylor's Version)
# Lyrics found for 'I Know Places (Taylor's Version)'
# Fetching lyrics for: Clean (Taylor's Version)
# Lyrics found for 'Clean (Taylor's Version)'
# Fetching lyrics for: Wonderland (Taylor's Version)
# Lyrics found for 'Wonderland (Taylor's Version)'
# Fetching lyrics for: You Are In Love (Taylor's Version)
# Lyrics found for 'You Are In Love (Taylor's Version)'
# Fetching lyrics for: New Romantics (Taylor's Version)
# Lyrics found for 'New Romantics (Taylor's Version)'
# Fetching lyrics for: "Slut!" (Taylor's Version) (From The Vault)
# Lyrics found for '"Slut!" (Taylor's Version) (From The Vault)'
# Fetching lyrics for: Say Don't Go (Taylor's Version) (From The Vault)
# Lyrics found for 'Say Don't Go (Taylor's Version) (From The Vault)'
# Fetching lyrics for: Now That We Don't Talk (Taylor's Version) (From The Vault)
# Lyrics found for 'Now That We Don't Talk (Taylor's Version) (From The Vault)'
# Fetching lyrics for: Suburban Legends (Taylor's Version) (From The Vault)
# Lyrics found for 'Suburban Legends (Taylor's Version) (From The Vault)'
# Fetching lyrics for: Mine (Taylor's Version)
# Lyrics found for 'Mine (Taylor's Version)'
# Fetching lyrics for: Sparks Fly (Taylor’s Version)
# Lyrics found for 'Sparks Fly (Taylor’s Version)'
# Fetching lyrics for: Back To December (Taylor's Version)
# Lyrics found for 'Back To December (Taylor's Version)'
# Fetching lyrics for: Speak Now (Taylor's Version)
# Lyrics found for 'Speak Now (Taylor's Version)'
# Fetching lyrics for: Dear John (Taylor's Version)
# Lyrics found for 'Dear John (Taylor's Version)'
# Fetching lyrics for: Mean (Taylor's Version)
# Lyrics found for 'Mean (Taylor's Version)'
# Fetching lyrics for: The Story Of Us (Taylor's Version)
# Lyrics found for 'The Story Of Us (Taylor's Version)'
# Fetching lyrics for: Never Grow Up (Taylor's Version)
# Lyrics found for 'Never Grow Up (Taylor's Version)'
# Fetching lyrics for: Enchanted (Taylor's Version)
# Lyrics found for 'Enchanted (Taylor's Version)'
# Fetching lyrics for: Better Than Revenge (Taylor's Version)
# Lyrics found for 'Better Than Revenge (Taylor's Version)'
# Fetching lyrics for: Innocent (Taylor's Version)
# Lyrics found for 'Innocent (Taylor's Version)'
# Fetching lyrics for: Haunted (Taylor's Version)
# Lyrics found for 'Haunted (Taylor's Version)'
# Fetching lyrics for: Last Kiss (Taylor's Version)
# Lyrics found for 'Last Kiss (Taylor's Version)'
# Fetching lyrics for: Long Live (Taylor's Version)
# Lyrics found for 'Long Live (Taylor's Version)'
# Fetching lyrics for: Ours (Taylor’s Version)
# Lyrics found for 'Ours (Taylor’s Version)'
# Fetching lyrics for: Superman (Taylor’s Version)
# Lyrics found for 'Superman (Taylor’s Version)'
# Fetching lyrics for: Electric Touch (feat. Fall Out Boy) (Taylor’s Version) (From The Vault)
# Lyrics found for 'Electric Touch (feat. Fall Out Boy) (Taylor’s Version) (From The Vault)'
# Fetching lyrics for: When Emma Falls in Love (Taylor’s Version) (From The Vault)
# Lyrics found for 'When Emma Falls in Love (Taylor’s Version) (From The Vault)'
# Fetching lyrics for: I Can See You (Taylor’s Version) (From The Vault)
# Lyrics found for 'I Can See You (Taylor’s Version) (From The Vault)'
# Fetching lyrics for: Castles Crumbling (feat. Hayley Williams) (Taylor’s Version) (From The Vault)
# Lyrics found for 'Castles Crumbling (feat. Hayley Williams) (Taylor’s Version) (From The Vault)'
# Fetching lyrics for: Lavender Haze
# Lyrics found for 'Lavender Haze'
# Fetching lyrics for: Maroon
# Lyrics found for 'Maroon'
# Fetching lyrics for: Anti-Hero
# Lyrics found for 'Anti-Hero'
# Fetching lyrics for: Snow On The Beach (feat. Lana Del Rey)
# Lyrics found for 'Snow On The Beach (feat. Lana Del Rey)'
# Fetching lyrics for: You're On Your Own, Kid
# Lyrics found for 'You're On Your Own, Kid'
# Fetching lyrics for: Midnight Rain
# Lyrics found for 'Midnight Rain'
# Fetching lyrics for: Question...?
# Lyrics found for 'Question...?'
# Fetching lyrics for: Vigilante Shit
# Lyrics found for 'Vigilante Shit'
# Fetching lyrics for: Bejeweled
# Lyrics found for 'Bejeweled'
# Fetching lyrics for: Labyrinth
# Lyrics found for 'Labyrinth'
# Fetching lyrics for: Karma
# Lyrics found for 'Karma'
# Fetching lyrics for: Sweet Nothing
# Lyrics found for 'Sweet Nothing'
# Fetching lyrics for: Mastermind
# Lyrics found for 'Mastermind'
# Fetching lyrics for: The Great War
# Lyrics found for 'The Great War'
# Fetching lyrics for: Bigger Than The Whole Sky
# Lyrics found for 'Bigger Than The Whole Sky'
# Fetching lyrics for: Paris
# Lyrics found for 'Paris'
# Fetching lyrics for: High Infidelity
# Lyrics found for 'High Infidelity'
# Fetching lyrics for: Glitch
# Lyrics found for 'Glitch'
# Fetching lyrics for: Would've, Could've, Should've
# Lyrics found for 'Would've, Could've, Should've'
# Fetching lyrics for: Dear Reader
# Lyrics found for 'Dear Reader'
# Fetching lyrics for: Lavender Haze
# Lyrics found for 'Lavender Haze'
# Fetching lyrics for: Maroon
# Lyrics found for 'Maroon'
# Fetching lyrics for: Anti-Hero
# Lyrics found for 'Anti-Hero'
# Fetching lyrics for: Snow On The Beach (feat. Lana Del Rey)
# Lyrics found for 'Snow On The Beach (feat. Lana Del Rey)'
# Fetching lyrics for: You're On Your Own, Kid
# Lyrics found for 'You're On Your Own, Kid'
# Fetching lyrics for: Midnight Rain
# Lyrics found for 'Midnight Rain'
# Fetching lyrics for: Question...?
# Lyrics found for 'Question...?'
# Fetching lyrics for: Vigilante Shit
# Lyrics found for 'Vigilante Shit'
# Fetching lyrics for: Bejeweled
# Lyrics found for 'Bejeweled'
# Fetching lyrics for: Labyrinth
# Lyrics found for 'Labyrinth'
# Fetching lyrics for: Karma
# Lyrics found for 'Karma'
# Fetching lyrics for: Sweet Nothing
# Lyrics found for 'Sweet Nothing'
# Fetching lyrics for: Mastermind
# Lyrics found for 'Mastermind'
# Fetching lyrics for: The Great War
# Lyrics found for 'The Great War'
# Fetching lyrics for: Bigger Than The Whole Sky
# Lyrics found for 'Bigger Than The Whole Sky'
# Fetching lyrics for: Paris
# Lyrics found for 'Paris'
# Fetching lyrics for: High Infidelity
# Lyrics found for 'High Infidelity'
# Fetching lyrics for: Glitch
# Lyrics found for 'Glitch'
# Fetching lyrics for: Would've, Could've, Should've
# Lyrics found for 'Would've, Could've, Should've'
# Fetching lyrics for: Dear Reader
# Lyrics found for 'Dear Reader'
# Fetching lyrics for: Lavender Haze
# Lyrics found for 'Lavender Haze'
# Fetching lyrics for: Maroon
# Lyrics found for 'Maroon'
# Fetching lyrics for: Anti-Hero
# Lyrics found for 'Anti-Hero'
# Fetching lyrics for: Snow On The Beach (feat. Lana Del Rey)
# Lyrics found for 'Snow On The Beach (feat. Lana Del Rey)'
# Fetching lyrics for: You're On Your Own, Kid
# Lyrics found for 'You're On Your Own, Kid'
# Fetching lyrics for: Midnight Rain
# Lyrics found for 'Midnight Rain'
# Fetching lyrics for: Question...?
# Lyrics found for 'Question...?'
# Fetching lyrics for: Vigilante Shit
# Lyrics found for 'Vigilante Shit'
# Fetching lyrics for: Bejeweled
# Lyrics found for 'Bejeweled'
# Fetching lyrics for: Labyrinth
# Lyrics found for 'Labyrinth'
# Fetching lyrics for: Karma
# Lyrics found for 'Karma'
# Fetching lyrics for: Sweet Nothing
# Lyrics found for 'Sweet Nothing'
# Fetching lyrics for: Mastermind
# Lyrics found for 'Mastermind'
# Fetching lyrics for: State Of Grace (Taylor's Version)
# Lyrics found for 'State Of Grace (Taylor's Version)'
# Fetching lyrics for: Red (Taylor's Version)
# Lyrics found for 'Red (Taylor's Version)'
# Fetching lyrics for: Treacherous (Taylor's Version)
# Lyrics found for 'Treacherous (Taylor's Version)'
# Fetching lyrics for: I Knew You Were Trouble (Taylor's Version)
# Lyrics found for 'I Knew You Were Trouble (Taylor's Version)'
# Fetching lyrics for: All Too Well (Taylor's Version)
# Lyrics found for 'All Too Well (Taylor's Version)'
# Fetching lyrics for: 22 (Taylor's Version)
# Lyrics found for '22 (Taylor's Version)'
# Fetching lyrics for: I Almost Do (Taylor's Version)
# Lyrics found for 'I Almost Do (Taylor's Version)'
# Fetching lyrics for: We Are Never Ever Getting Back Together (Taylor's Version)
# Lyrics found for 'We Are Never Ever Getting Back Together (Taylor's Version)'
# Fetching lyrics for: Stay Stay Stay (Taylor's Version)
# Lyrics found for 'Stay Stay Stay (Taylor's Version)'
# Fetching lyrics for: The Last Time (feat. Gary Lightbody of Snow Patrol) (Taylor’s Version)
# Lyrics found for 'The Last Time (feat. Gary Lightbody of Snow Patrol) (Taylor’s Version)'
# Fetching lyrics for: Holy Ground (Taylor's Version)
# Lyrics found for 'Holy Ground (Taylor's Version)'
# Fetching lyrics for: Sad Beautiful Tragic (Taylor's Version)
# Lyrics found for 'Sad Beautiful Tragic (Taylor's Version)'
# Fetching lyrics for: The Lucky One (Taylor's Version)
# Lyrics found for 'The Lucky One (Taylor's Version)'
# Fetching lyrics for: Everything Has Changed (feat. Ed Sheeran) (Taylor’s Version)
# Lyrics found for 'Everything Has Changed (feat. Ed Sheeran) (Taylor’s Version)'
# Fetching lyrics for: Starlight (Taylor's Version)
# Lyrics found for 'Starlight (Taylor's Version)'
# Fetching lyrics for: Begin Again (Taylor's Version)
# Lyrics found for 'Begin Again (Taylor's Version)'
# Fetching lyrics for: The Moment I Knew (Taylor's Version)
# Lyrics found for 'The Moment I Knew (Taylor's Version)'
# Fetching lyrics for: Come Back...Be Here (Taylor's Version)
# Lyrics found for 'Come Back...Be Here (Taylor's Version)'
# Fetching lyrics for: Girl At Home (Taylor's Version)
# Lyrics found for 'Girl At Home (Taylor's Version)'
# Fetching lyrics for: State Of Grace (Acoustic Version) (Taylor's Version)
# Lyrics found for 'State Of Grace (Acoustic Version) (Taylor's Version)'
# Fetching lyrics for: Fearless (Taylor’s Version)
# Lyrics found for 'Fearless (Taylor’s Version)'
# Fetching lyrics for: Fifteen (Taylor’s Version)
# Lyrics found for 'Fifteen (Taylor’s Version)'
# Fetching lyrics for: Love Story (Taylor’s Version)
# Lyrics found for 'Love Story (Taylor’s Version)'
# Fetching lyrics for: Hey Stephen (Taylor’s Version)
# Lyrics found for 'Hey Stephen (Taylor’s Version)'
# Fetching lyrics for: White Horse (Taylor’s Version)
# Lyrics found for 'White Horse (Taylor’s Version)'
# Fetching lyrics for: You Belong With Me (Taylor’s Version)
# Lyrics found for 'You Belong With Me (Taylor’s Version)'
# Fetching lyrics for: Breathe (feat. Colbie Caillat) (Taylor’s Version)
# Lyrics found for 'Breathe (feat. Colbie Caillat) (Taylor’s Version)'
# Fetching lyrics for: Tell Me Why (Taylor’s Version)
# Lyrics found for 'Tell Me Why (Taylor’s Version)'
# Fetching lyrics for: You’re Not Sorry (Taylor’s Version)
# Lyrics found for 'You’re Not Sorry (Taylor’s Version)'
# Fetching lyrics for: The Way I Loved You (Taylor’s Version)
# Lyrics found for 'The Way I Loved You (Taylor’s Version)'
# Fetching lyrics for: Forever & Always (Taylor’s Version)
# Lyrics found for 'Forever & Always (Taylor’s Version)'
# Fetching lyrics for: The Best Day (Taylor’s Version)
# Lyrics found for 'The Best Day (Taylor’s Version)'
# Fetching lyrics for: Change (Taylor’s Version)
# Lyrics found for 'Change (Taylor’s Version)'
# Fetching lyrics for: Jump Then Fall (Taylor’s Version)
# Lyrics found for 'Jump Then Fall (Taylor’s Version)'
# Fetching lyrics for: Untouchable (Taylor’s Version)
# Lyrics found for 'Untouchable (Taylor’s Version)'
# Fetching lyrics for: Forever & Always (Piano Version) (Taylor’s Version)
# Lyrics found for 'Forever & Always (Piano Version) (Taylor’s Version)'
# Fetching lyrics for: Come In With The Rain (Taylor’s Version)
# Lyrics found for 'Come In With The Rain (Taylor’s Version)'
# Fetching lyrics for: Superstar (Taylor’s Version)
# Lyrics found for 'Superstar (Taylor’s Version)'
# Fetching lyrics for: The Other Side Of The Door (Taylor’s Version)
# Lyrics found for 'The Other Side Of The Door (Taylor’s Version)'
# Fetching lyrics for: Today Was A Fairytale (Taylor’s Version)
# Lyrics found for 'Today Was A Fairytale (Taylor’s Version)'
# Fetching lyrics for: willow
# Lyrics found for 'willow'
# Fetching lyrics for: champagne problems
# Lyrics found for 'champagne problems'
# Fetching lyrics for: gold rush
# Lyrics found for 'gold rush'
# Fetching lyrics for: ‘tis the damn season
# Lyrics found for '‘tis the damn season'
# Fetching lyrics for: tolerate it
# Lyrics found for 'tolerate it'
# Fetching lyrics for: no body, no crime (feat. HAIM)
# Lyrics found for 'no body, no crime (feat. HAIM)'
# Fetching lyrics for: happiness
# Lyrics found for 'happiness'
# Fetching lyrics for: dorothea
# Lyrics found for 'dorothea'
# Fetching lyrics for: coney island (feat. The National)
# Lyrics found for 'coney island (feat. The National)'
# Fetching lyrics for: ivy
# Lyrics found for 'ivy'
# Fetching lyrics for: cowboy like me
# Lyrics found for 'cowboy like me'
# Fetching lyrics for: long story short
# Lyrics found for 'long story short'
# Fetching lyrics for: marjorie
# Lyrics found for 'marjorie'
# Fetching lyrics for: closure
# Lyrics found for 'closure'
# Fetching lyrics for: evermore (feat. Bon Iver)
# Lyrics found for 'evermore (feat. Bon Iver)'
# Fetching lyrics for: right where you left me - bonus track
# Lyrics found for 'right where you left me - bonus track'
# Fetching lyrics for: it’s time to go - bonus track
# Lyrics found for 'it’s time to go - bonus track'
# Fetching lyrics for: willow
# Lyrics found for 'willow'
# Fetching lyrics for: champagne problems
# Lyrics found for 'champagne problems'
# Fetching lyrics for: gold rush
# Lyrics found for 'gold rush'
# Fetching lyrics for: ‘tis the damn season
# Lyrics found for '‘tis the damn season'
# Fetching lyrics for: tolerate it
# Lyrics found for 'tolerate it'
# Fetching lyrics for: no body, no crime (feat. HAIM)
# Lyrics found for 'no body, no crime (feat. HAIM)'
# Fetching lyrics for: happiness
# Lyrics found for 'happiness'
# Fetching lyrics for: dorothea
# Lyrics found for 'dorothea'
# Fetching lyrics for: coney island (feat. The National)
# Lyrics found for 'coney island (feat. The National)'
# Fetching lyrics for: ivy
# Lyrics found for 'ivy'
# Fetching lyrics for: cowboy like me
# Lyrics found for 'cowboy like me'
# Fetching lyrics for: long story short
# Lyrics found for 'long story short'
# Fetching lyrics for: marjorie
# Lyrics found for 'marjorie'
# Fetching lyrics for: closure
# Lyrics found for 'closure'
# Fetching lyrics for: evermore (feat. Bon Iver)
# Lyrics found for 'evermore (feat. Bon Iver)'
# Fetching lyrics for: the 1
# Lyrics found for 'the 1'
# Fetching lyrics for: cardigan
# Lyrics found for 'cardigan'
# Fetching lyrics for: the last great american dynasty
# Lyrics found for 'the last great american dynasty'
# Fetching lyrics for: exile (feat. Bon Iver)
# Lyrics found for 'exile (feat. Bon Iver)'
# Fetching lyrics for: my tears ricochet
# Lyrics found for 'my tears ricochet'
# Fetching lyrics for: mirrorball
# Lyrics found for 'mirrorball'
# Fetching lyrics for: seven
# Lyrics found for 'seven'
# Fetching lyrics for: august
# Lyrics found for 'august'
# Fetching lyrics for: this is me trying
# Lyrics found for 'this is me trying'
# Fetching lyrics for: illicit affairs
# Lyrics found for 'illicit affairs'
# Fetching lyrics for: invisible string
# Lyrics found for 'invisible string'
# Fetching lyrics for: mad woman
# Lyrics found for 'mad woman'
# Fetching lyrics for: epiphany
# Lyrics found for 'epiphany'
# Fetching lyrics for: betty
# Lyrics found for 'betty'
# Fetching lyrics for: peace
# Lyrics found for 'peace'
# Fetching lyrics for: hoax
# Lyrics found for 'hoax'
# Fetching lyrics for: the lakes - bonus track
# Lyrics found for 'the lakes - bonus track'
# Fetching lyrics for: the 1 - the long pond studio sessions
# Lyrics found for 'the 1 - the long pond studio sessions'
# Fetching lyrics for: cardigan - the long pond studio sessions
# Lyrics found for 'cardigan - the long pond studio sessions'
# Fetching lyrics for: the last great american dynasty - the long pond studio sessions
# Lyrics found for 'the last great american dynasty - the long pond studio sessions'
# Fetching lyrics for: the 1
# Lyrics found for 'the 1'
# Fetching lyrics for: cardigan
# Lyrics found for 'cardigan'
# Fetching lyrics for: the last great american dynasty
# Lyrics found for 'the last great american dynasty'
# Fetching lyrics for: exile (feat. Bon Iver)
# Lyrics found for 'exile (feat. Bon Iver)'
# Fetching lyrics for: my tears ricochet
# Lyrics found for 'my tears ricochet'
# Fetching lyrics for: mirrorball
# Lyrics found for 'mirrorball'
# Fetching lyrics for: seven
# Lyrics found for 'seven'
# Fetching lyrics for: august
# Lyrics found for 'august'
# Fetching lyrics for: this is me trying
# Lyrics found for 'this is me trying'
# Fetching lyrics for: illicit affairs
# Lyrics found for 'illicit affairs'
# Fetching lyrics for: invisible string
# Lyrics found for 'invisible string'
# Fetching lyrics for: mad woman
# Lyrics found for 'mad woman'
# Fetching lyrics for: epiphany
# Lyrics found for 'epiphany'
# Fetching lyrics for: betty
# Lyrics found for 'betty'
# Fetching lyrics for: peace
# Lyrics found for 'peace'
# Fetching lyrics for: hoax
# Lyrics found for 'hoax'
# Fetching lyrics for: the lakes - bonus track
# Lyrics found for 'the lakes - bonus track'
# Fetching lyrics for: the 1
# Lyrics found for 'the 1'
# Fetching lyrics for: cardigan
# Lyrics found for 'cardigan'
# Fetching lyrics for: the last great american dynasty
# Lyrics found for 'the last great american dynasty'
# Fetching lyrics for: exile (feat. Bon Iver)
# Lyrics found for 'exile (feat. Bon Iver)'
# Fetching lyrics for: my tears ricochet
# Lyrics found for 'my tears ricochet'
# Fetching lyrics for: mirrorball
# Lyrics found for 'mirrorball'
# Fetching lyrics for: seven
# Lyrics found for 'seven'
# Fetching lyrics for: august
# Lyrics found for 'august'
# Fetching lyrics for: this is me trying
# Lyrics found for 'this is me trying'
# Fetching lyrics for: illicit affairs
# Lyrics found for 'illicit affairs'
# Fetching lyrics for: invisible string
# Lyrics found for 'invisible string'
# Fetching lyrics for: mad woman
# Lyrics found for 'mad woman'
# Fetching lyrics for: epiphany
# Lyrics found for 'epiphany'
# Fetching lyrics for: betty
# Lyrics found for 'betty'
# Fetching lyrics for: peace
# Lyrics found for 'peace'
# Fetching lyrics for: hoax
# Lyrics found for 'hoax'
# Fetching lyrics for: I Forgot That You Existed
# Lyrics found for 'I Forgot That You Existed'
# Fetching lyrics for: Cruel Summer
# Lyrics found for 'Cruel Summer'
# Fetching lyrics for: Lover
# Lyrics found for 'Lover'
# Fetching lyrics for: The Man
# Lyrics found for 'The Man'
# Fetching lyrics for: The Archer
# Lyrics found for 'The Archer'
# Fetching lyrics for: I Think He Knows
# Lyrics found for 'I Think He Knows'
# Fetching lyrics for: Miss Americana & The Heartbreak Prince
# Lyrics found for 'Miss Americana & The Heartbreak Prince'
# Fetching lyrics for: Paper Rings
# Lyrics found for 'Paper Rings'
# Fetching lyrics for: Cornelia Street
# Lyrics found for 'Cornelia Street'
# Fetching lyrics for: Death By A Thousand Cuts
# Lyrics found for 'Death By A Thousand Cuts'
# Fetching lyrics for: London Boy
# Lyrics found for 'London Boy'
# Fetching lyrics for: Soon You’ll Get Better (feat. The Chicks)
# Lyrics found for 'Soon You’ll Get Better (feat. The Chicks)'
# Fetching lyrics for: False God
# Lyrics found for 'False God'
# Fetching lyrics for: You Need To Calm Down
# Lyrics found for 'You Need To Calm Down'
# Fetching lyrics for: Afterglow
# Lyrics found for 'Afterglow'
# Fetching lyrics for: ME! (feat. Brendon Urie of Panic! At The Disco)
# Lyrics found for 'ME! (feat. Brendon Urie of Panic! At The Disco)'
# Fetching lyrics for: It’s Nice To Have A Friend
# Lyrics found for 'It’s Nice To Have A Friend'
# Fetching lyrics for: Daylight
# Lyrics found for 'Daylight'
# Fetching lyrics for: ...Ready For It?
# Lyrics found for '...Ready For It?'
# Fetching lyrics for: End Game
# Lyrics found for 'End Game'
# Fetching lyrics for: I Did Something Bad
# Lyrics found for 'I Did Something Bad'
# Fetching lyrics for: Don’t Blame Me
# Lyrics found for 'Don’t Blame Me'
# Fetching lyrics for: Delicate
# Lyrics found for 'Delicate'
# Fetching lyrics for: Look What You Made Me Do
# Lyrics found for 'Look What You Made Me Do'
# Fetching lyrics for: So It Goes...
# Lyrics found for 'So It Goes...'
# Fetching lyrics for: Gorgeous
# Lyrics found for 'Gorgeous'
# Fetching lyrics for: Getaway Car
# Lyrics found for 'Getaway Car'
# Fetching lyrics for: King Of My Heart
# Lyrics found for 'King Of My Heart'
# Fetching lyrics for: Dancing With Our Hands Tied
# Lyrics found for 'Dancing With Our Hands Tied'
# Fetching lyrics for: Dress
# Lyrics found for 'Dress'
# Fetching lyrics for: This Is Why We Can't Have Nice Things
# Lyrics found for 'This Is Why We Can't Have Nice Things'
# Fetching lyrics for: Call It What You Want
# Lyrics found for 'Call It What You Want'
# Fetching lyrics for: New Year’s Day
# Lyrics found for 'New Year’s Day'
# Fetching lyrics for: All Too Well
# Lyrics found for 'All Too Well'
# Fetching lyrics for: Wildest Dreams
# Lyrics found for 'Wildest Dreams'
# Fetching lyrics for: The Best Day
# Lyrics found for 'The Best Day'
# Fetching lyrics for: Red
# Lyrics found for 'Red'
# Fetching lyrics for: Holy Ground
# Lyrics found for 'Holy Ground'
# Fetching lyrics for: Teardrops On My Guitar - Radio Single Remix
# Lyrics found for 'Teardrops On My Guitar - Radio Single Remix'
# Fetching lyrics for: Our Song
# Lyrics found for 'Our Song'
# Fetching lyrics for: 22
# Lyrics found for '22'
# Fetching lyrics for: I Knew You Were Trouble.
# Lyrics found for 'I Knew You Were Trouble.'
# Fetching lyrics for: I Don’t Wanna Live Forever (Fifty Shades Darker)
# Lyrics found for 'I Don’t Wanna Live Forever (Fifty Shades Darker)'
# Fetching lyrics for: Mean
# Lyrics found for 'Mean'
# Fetching lyrics for: How You Get The Girl
# Lyrics found for 'How You Get The Girl'
# Fetching lyrics for: So It Goes...
# Lyrics found for 'So It Goes...'
# Fetching lyrics for: Fifteen
# Lyrics found for 'Fifteen'
# Fetching lyrics for: Mine
# Lyrics found for 'Mine'
# Fetching lyrics for: Sparks Fly
# Lyrics found for 'Sparks Fly'
# Fetching lyrics for: State Of Grace
# Lyrics found for 'State Of Grace'
# Fetching lyrics for: Haunted
# Lyrics found for 'Haunted'
# Fetching lyrics for: Never Grow Up
# Lyrics found for 'Never Grow Up'
# Fetching lyrics for: Treacherous
# Lyrics found for 'Treacherous'
# Fetching lyrics for: Welcome To New York
# Lyrics found for 'Welcome To New York'
# Fetching lyrics for: Blank Space
# Lyrics found for 'Blank Space'
# Fetching lyrics for: Style
# Lyrics found for 'Style'
# Fetching lyrics for: Out Of The Woods
# Lyrics found for 'Out Of The Woods'
# Fetching lyrics for: All You Had To Do Was Stay
# Lyrics found for 'All You Had To Do Was Stay'
# Fetching lyrics for: Shake It Off
# Lyrics found for 'Shake It Off'
# Fetching lyrics for: I Wish You Would
# Lyrics found for 'I Wish You Would'
# Fetching lyrics for: Bad Blood
# Lyrics found for 'Bad Blood'
# Fetching lyrics for: Wildest Dreams
# Lyrics found for 'Wildest Dreams'
# Fetching lyrics for: How You Get The Girl
# Lyrics found for 'How You Get The Girl'
# Fetching lyrics for: This Love
# Lyrics found for 'This Love'
# Fetching lyrics for: I Know Places
# Lyrics found for 'I Know Places'
# Fetching lyrics for: Clean
# Lyrics found for 'Clean'
# Fetching lyrics for: Wonderland
# Lyrics found for 'Wonderland'
# Fetching lyrics for: You Are In Love
# Lyrics found for 'You Are In Love'
# Fetching lyrics for: New Romantics
# Lyrics found for 'New Romantics'
# Fetching lyrics for: I Know Places - Voice Memo
# Lyrics found for 'I Know Places - Voice Memo'
# Fetching lyrics for: I Wish You Would - Voice Memo
# Lyrics found for 'I Wish You Would - Voice Memo'
# Fetching lyrics for: Blank Space - Voice Memo
# Lyrics found for 'Blank Space - Voice Memo'
# Fetching lyrics for: Welcome To New York
# Lyrics found for 'Welcome To New York'
# Fetching lyrics for: Blank Space
# Lyrics found for 'Blank Space'
# Fetching lyrics for: Style
# Lyrics found for 'Style'
# Fetching lyrics for: Out Of The Woods
# Lyrics found for 'Out Of The Woods'
# Fetching lyrics for: All You Had To Do Was Stay
# Lyrics found for 'All You Had To Do Was Stay'
# Fetching lyrics for: Shake It Off
# Lyrics found for 'Shake It Off'
# Fetching lyrics for: I Wish You Would
# Lyrics found for 'I Wish You Would'
# Fetching lyrics for: Bad Blood
# Lyrics found for 'Bad Blood'
# Fetching lyrics for: Wildest Dreams
# Lyrics found for 'Wildest Dreams'
# Fetching lyrics for: How You Get The Girl
# Lyrics found for 'How You Get The Girl'
# Fetching lyrics for: This Love
# Lyrics found for 'This Love'
# Fetching lyrics for: I Know Places
# Lyrics found for 'I Know Places'
# Fetching lyrics for: Clean
# Lyrics found for 'Clean'
# Fetching lyrics for: State Of Grace
# Lyrics found for 'State Of Grace'
# Fetching lyrics for: Red
# Lyrics found for 'Red'
# Fetching lyrics for: Treacherous
# Lyrics found for 'Treacherous'
# Fetching lyrics for: I Knew You Were Trouble.
# Lyrics found for 'I Knew You Were Trouble.'
# Fetching lyrics for: All Too Well
# Lyrics found for 'All Too Well'
# Fetching lyrics for: 22
# Lyrics found for '22'
# Fetching lyrics for: I Almost Do
# Lyrics found for 'I Almost Do'
# Fetching lyrics for: We Are Never Ever Getting Back Together
# Lyrics found for 'We Are Never Ever Getting Back Together'
# Fetching lyrics for: Stay Stay Stay
# Lyrics found for 'Stay Stay Stay'
# Fetching lyrics for: The Last Time
# Lyrics found for 'The Last Time'
# Fetching lyrics for: Holy Ground
# Lyrics found for 'Holy Ground'
# Fetching lyrics for: Sad Beautiful Tragic
# Lyrics found for 'Sad Beautiful Tragic'
# Fetching lyrics for: The Lucky One
# Lyrics found for 'The Lucky One'
# Fetching lyrics for: Everything Has Changed
# Lyrics found for 'Everything Has Changed'
# Fetching lyrics for: Starlight
# Lyrics found for 'Starlight'
# Fetching lyrics for: Begin Again
# Lyrics found for 'Begin Again'
# Fetching lyrics for: The Moment I Knew
# Lyrics found for 'The Moment I Knew'
# Fetching lyrics for: Come Back...Be Here
# Lyrics found for 'Come Back...Be Here'
# Fetching lyrics for: Girl At Home
# Lyrics found for 'Girl At Home'
# Fetching lyrics for: Treacherous - Original Demo Recording
# Lyrics found for 'Treacherous - Original Demo Recording'
# Fetching lyrics for: State Of Grace
# Lyrics found for 'State Of Grace'
# Fetching lyrics for: Red
# Lyrics found for 'Red'
# Fetching lyrics for: Treacherous
# Lyrics found for 'Treacherous'
# Fetching lyrics for: I Knew You Were Trouble.
# Lyrics found for 'I Knew You Were Trouble.'
# Fetching lyrics for: All Too Well
# Lyrics found for 'All Too Well'
# Fetching lyrics for: 22
# Lyrics found for '22'
# Fetching lyrics for: I Almost Do
# Lyrics found for 'I Almost Do'
# Fetching lyrics for: We Are Never Ever Getting Back Together
# Lyrics found for 'We Are Never Ever Getting Back Together'
# Fetching lyrics for: Stay Stay Stay
# Lyrics found for 'Stay Stay Stay'
# Fetching lyrics for: The Last Time
# Lyrics found for 'The Last Time'
# Fetching lyrics for: Holy Ground
# Lyrics found for 'Holy Ground'
# Fetching lyrics for: Sad Beautiful Tragic
# Lyrics found for 'Sad Beautiful Tragic'
# Fetching lyrics for: The Lucky One
# Lyrics found for 'The Lucky One'
# Fetching lyrics for: Everything Has Changed
# Lyrics found for 'Everything Has Changed'
# Fetching lyrics for: Starlight
# Lyrics found for 'Starlight'
# Fetching lyrics for: Begin Again
# Lyrics found for 'Begin Again'
# Fetching lyrics for: Sparks Fly - Live/2011
# Lyrics found for 'Sparks Fly - Live/2011'
# Fetching lyrics for: Mine - Live/2011
# Lyrics found for 'Mine - Live/2011'
# Fetching lyrics for: The Story Of Us - Live
# Lyrics found for 'The Story Of Us - Live'
# Fetching lyrics for: Mean - Live/2011
# Lyrics found for 'Mean - Live/2011'
# Fetching lyrics for: Ours - Live/2011
# Lyrics found for 'Ours - Live/2011'
# Fetching lyrics for: Back To December/Apologize/You're Not Sorry - Live/2011/Medley
# Lyrics found for 'Back To December/Apologize/You're Not Sorry - Live/2011/Medley'
# Fetching lyrics for: Better Than Revenge - Live/2011
# Lyrics found for 'Better Than Revenge - Live/2011'
# Fetching lyrics for: Speak Now - Live/2011
# Lyrics found for 'Speak Now - Live/2011'
# Fetching lyrics for: Last Kiss - Live/2011
# Lyrics found for 'Last Kiss - Live/2011'
# Fetching lyrics for: Drops Of Jupiter - Live/2011
# Lyrics found for 'Drops Of Jupiter - Live/2011'
# Fetching lyrics for: Bette Davis Eyes - Live/2011
# Lyrics found for 'Bette Davis Eyes - Live/2011'
# Fetching lyrics for: I Want You Back - Live/2011
# Lyrics found for 'I Want You Back - Live/2011'
# Fetching lyrics for: Dear John - Live/2011
# Lyrics found for 'Dear John - Live/2011'
# Fetching lyrics for: Enchanted - Live/2011
# Lyrics found for 'Enchanted - Live/2011'
# Fetching lyrics for: Haunted - Live/2011
# Lyrics found for 'Haunted - Live/2011'
# Fetching lyrics for: Long Live - Live/2011
# Lyrics found for 'Long Live - Live/2011'
# Fetching lyrics for: Mine
# Lyrics found for 'Mine'
# Fetching lyrics for: Sparks Fly
# Lyrics found for 'Sparks Fly'
# Fetching lyrics for: Back To December
# Lyrics found for 'Back To December'
# Fetching lyrics for: Speak Now
# Lyrics found for 'Speak Now'
# Fetching lyrics for: Dear John
# Lyrics found for 'Dear John'
# Fetching lyrics for: Mean
# Lyrics found for 'Mean'
# Fetching lyrics for: The Story Of Us
# Lyrics found for 'The Story Of Us'
# Fetching lyrics for: Never Grow Up
# Lyrics found for 'Never Grow Up'
# Fetching lyrics for: Enchanted
# Lyrics found for 'Enchanted'
# Fetching lyrics for: Better Than Revenge
# Lyrics found for 'Better Than Revenge'
# Fetching lyrics for: Innocent
# Lyrics found for 'Innocent'
# Fetching lyrics for: Haunted
# Lyrics found for 'Haunted'
# Fetching lyrics for: Last Kiss
# Lyrics found for 'Last Kiss'
# Fetching lyrics for: Long Live
# Lyrics found for 'Long Live'
# Fetching lyrics for: Ours
# Lyrics found for 'Ours'
# Fetching lyrics for: If This Was A Movie
# Lyrics found for 'If This Was A Movie'
# Fetching lyrics for: Superman
# Lyrics found for 'Superman'
# Fetching lyrics for: Back To December - Acoustic
# Lyrics found for 'Back To December - Acoustic'
# Fetching lyrics for: Haunted - Acoustic Version
# Lyrics found for 'Haunted - Acoustic Version'
# Fetching lyrics for: Mine - POP Mix
# Lyrics found for 'Mine - POP Mix'
# Fetching lyrics for: Mine
# Lyrics found for 'Mine'
# Fetching lyrics for: Sparks Fly
# Lyrics found for 'Sparks Fly'
# Fetching lyrics for: Back To December
# Lyrics found for 'Back To December'
# Fetching lyrics for: Speak Now
# Lyrics found for 'Speak Now'
# Fetching lyrics for: Dear John
# Lyrics found for 'Dear John'
# Fetching lyrics for: Mean
# Lyrics found for 'Mean'
# Fetching lyrics for: The Story Of Us
# Lyrics found for 'The Story Of Us'
# Fetching lyrics for: Never Grow Up
# Lyrics found for 'Never Grow Up'
# Fetching lyrics for: Enchanted
# Lyrics found for 'Enchanted'
# Fetching lyrics for: Better Than Revenge
# Lyrics found for 'Better Than Revenge'
# Fetching lyrics for: Innocent
# Lyrics found for 'Innocent'
# Fetching lyrics for: Haunted
# Lyrics found for 'Haunted'
# Fetching lyrics for: Last Kiss
# Lyrics found for 'Last Kiss'
# Fetching lyrics for: Long Live
# Lyrics found for 'Long Live'
# Fetching lyrics for: Jump Then Fall
# Lyrics found for 'Jump Then Fall'
# Fetching lyrics for: Untouchable
# Lyrics found for 'Untouchable'
# Fetching lyrics for: Forever & Always - Piano Version
# Lyrics found for 'Forever & Always - Piano Version'
# Fetching lyrics for: Come In With The Rain
# Lyrics found for 'Come In With The Rain'
# Fetching lyrics for: SuperStar
# Lyrics found for 'SuperStar'
# Fetching lyrics for: The Other Side Of The Door
# Lyrics found for 'The Other Side Of The Door'
# Fetching lyrics for: Fearless
# Lyrics found for 'Fearless'
# Fetching lyrics for: Fifteen
# Lyrics found for 'Fifteen'
# Fetching lyrics for: Love Story
# Lyrics found for 'Love Story'
# Fetching lyrics for: Hey Stephen
# Lyrics found for 'Hey Stephen'
# Fetching lyrics for: White Horse
# Lyrics found for 'White Horse'
# Fetching lyrics for: You Belong With Me
# Lyrics found for 'You Belong With Me'
# Fetching lyrics for: Breathe
# Lyrics found for 'Breathe'
# Fetching lyrics for: Tell Me Why
# Lyrics found for 'Tell Me Why'
# Fetching lyrics for: You're Not Sorry
# Lyrics found for 'You're Not Sorry'
# Fetching lyrics for: The Way I Loved You
# Lyrics found for 'The Way I Loved You'
# Fetching lyrics for: Forever & Always
# Lyrics found for 'Forever & Always'
# Fetching lyrics for: The Best Day
# Lyrics found for 'The Best Day'
# Fetching lyrics for: Change
# Lyrics found for 'Change'
# Fetching lyrics for: Fearless
# Lyrics found for 'Fearless'
# Fetching lyrics for: Fifteen
# Lyrics found for 'Fifteen'
# Fetching lyrics for: Love Story
# Lyrics found for 'Love Story'
# Fetching lyrics for: Hey Stephen
# Lyrics found for 'Hey Stephen'
# Fetching lyrics for: White Horse
# Lyrics found for 'White Horse'
# Fetching lyrics for: You Belong With Me
# Lyrics found for 'You Belong With Me'
# Fetching lyrics for: Breathe
# Lyrics found for 'Breathe'
# Fetching lyrics for: Tell Me Why
# Lyrics found for 'Tell Me Why'
# Fetching lyrics for: You're Not Sorry
# Lyrics found for 'You're Not Sorry'
# Fetching lyrics for: The Way I Loved You
# Lyrics found for 'The Way I Loved You'
# Fetching lyrics for: Forever & Always
# Lyrics found for 'Forever & Always'
# Fetching lyrics for: The Best Day
# Lyrics found for 'The Best Day'
# Fetching lyrics for: Change
# Lyrics found for 'Change'
# Fetching lyrics for: Love Story - Live From Clear Channel Stripped 2008
# Lyrics found for 'Love Story - Live From Clear Channel Stripped 2008'
# Fetching lyrics for: Fearless - Live From Clear Channel Stripped 2008
# Lyrics found for 'Fearless - Live From Clear Channel Stripped 2008'
# Fetching lyrics for: Beautiful Eyes - Live From Clear Channel Stripped 2008
# Lyrics found for 'Beautiful Eyes - Live From Clear Channel Stripped 2008'
# Fetching lyrics for: Untouchable - Live From Clear Channel Stripped 2008
# Lyrics found for 'Untouchable - Live From Clear Channel Stripped 2008'
# Fetching lyrics for: Teardrops On My Guitar - Live From Clear Channel Stripped 2008
# Lyrics found for 'Teardrops On My Guitar - Live From Clear Channel Stripped 2008'
# Fetching lyrics for: Picture To Burn - Live From Clear Channel Stripped 2008
# Lyrics found for 'Picture To Burn - Live From Clear Channel Stripped 2008'
# Fetching lyrics for: Should've Said No - Live From Clear Channel Stripped 2008
# Lyrics found for 'Should've Said No - Live From Clear Channel Stripped 2008'
# Fetching lyrics for: Change - Live From Clear Channel Stripped 2008
# Lyrics found for 'Change - Live From Clear Channel Stripped 2008'
# Fetching lyrics for: Tim McGraw
# Lyrics found for 'Tim McGraw'
# Fetching lyrics for: Picture To Burn
# Lyrics found for 'Picture To Burn'
# Fetching lyrics for: Teardrops On My Guitar - Radio Single Remix
# Lyrics found for 'Teardrops On My Guitar - Radio Single Remix'
# Fetching lyrics for: A Place in this World
# Lyrics found for 'A Place in this World'
# Fetching lyrics for: Cold As You
# Lyrics found for 'Cold As You'
# Fetching lyrics for: The Outside
# Lyrics found for 'The Outside'
# Fetching lyrics for: Tied Together with a Smile
# Lyrics found for 'Tied Together with a Smile'
# Fetching lyrics for: Stay Beautiful
# Lyrics found for 'Stay Beautiful'
# Fetching lyrics for: Should've Said No
# Lyrics found for 'Should've Said No'
# Fetching lyrics for: Mary's Song (Oh My My My)
# Lyrics found for 'Mary's Song (Oh My My My)'
# Fetching lyrics for: Our Song
# Lyrics found for 'Our Song'
# Fetching lyrics for: I'm Only Me When I'm With You
# Lyrics found for 'I'm Only Me When I'm With You'
# Fetching lyrics for: Invisible
# Lyrics found for 'Invisible'
# Fetching lyrics for: A Perfectly Good Heart
# Lyrics found for 'A Perfectly Good Heart'
# Fetching lyrics for: Teardrops on My Guitar - Pop Version
# Lyrics found for 'Teardrops on My Guitar - Pop Version'
# Fetching lyrics for: I Can Do It With a Broken Heart - Dombresky Remix
# Lyrics found for 'I Can Do It With a Broken Heart - Dombresky Remix'
# Fetching lyrics for: I Can Do It With a Broken Heart
# Lyrics found for 'I Can Do It With a Broken Heart'
# Fetching lyrics for: I Can Do It With a Broken Heart - Instrumental
# Lyrics found for 'I Can Do It With a Broken Heart - Instrumental'
# Fetching lyrics for: I Can Do It With a Broken Heart
# Lyrics found for 'I Can Do It With a Broken Heart'
# Fetching lyrics for: I Can Do It With a Broken Heart - Instrumental
# Lyrics found for 'I Can Do It With a Broken Heart - Instrumental'
# Fetching lyrics for: Fortnight (feat. Post Malone) - Acoustic Version
# Lyrics found for 'Fortnight (feat. Post Malone) - Acoustic Version'
# Fetching lyrics for: Fortnight (feat. Post Malone) - Cults Remix
# Lyrics found for 'Fortnight (feat. Post Malone) - Cults Remix'
# Fetching lyrics for: Fortnight (feat. Post Malone)
# Lyrics found for 'Fortnight (feat. Post Malone)'
# Fetching lyrics for: Fortnight (feat. Post Malone) - BLOND:ISH Remix
# Lyrics found for 'Fortnight (feat. Post Malone) - BLOND:ISH Remix'
# Fetching lyrics for: Fortnight (feat. Post Malone)
# Lyrics found for 'Fortnight (feat. Post Malone)'
# Fetching lyrics for: You’re Losing Me (From The Vault)
# Lyrics found for 'You’re Losing Me (From The Vault)'
# Fetching lyrics for: Cruel Summer - Live from TS | The Eras Tour
# Lyrics found for 'Cruel Summer - Live from TS | The Eras Tour'
# Fetching lyrics for: Cruel Summer - LP Giobbi Remix
# Lyrics found for 'Cruel Summer - LP Giobbi Remix'
# Fetching lyrics for: Cruel Summer - LP Giobbi Remix - Extended Version
# Lyrics found for 'Cruel Summer - LP Giobbi Remix - Extended Version'
# Fetching lyrics for: Cruel Summer
# Lyrics found for 'Cruel Summer'
# Fetching lyrics for: Lavender Haze - Acoustic Version
# Lyrics found for 'Lavender Haze - Acoustic Version'
# Fetching lyrics for: Lavender Haze - Tensnake Remix
# Lyrics found for 'Lavender Haze - Tensnake Remix'
# Fetching lyrics for: Lavender Haze - Snakehips Remix
# Lyrics found for 'Lavender Haze - Snakehips Remix'
# Fetching lyrics for: Lavender Haze - Jungle Remix
# Lyrics found for 'Lavender Haze - Jungle Remix'
# Fetching lyrics for: Lavender Haze - Felix Jaehn Remix
# Lyrics found for 'Lavender Haze - Felix Jaehn Remix'
# Fetching lyrics for: Lavender Haze
# Lyrics found for 'Lavender Haze'
# Fetching lyrics for: Lavender Haze - Felix Jaehn Remix
# Lyrics found for 'Lavender Haze - Felix Jaehn Remix'
# Fetching lyrics for: Anti-Hero - Acoustic Version
# Lyrics found for 'Anti-Hero - Acoustic Version'
# Fetching lyrics for: Anti-Hero - ILLENIUM Remix
# Lyrics found for 'Anti-Hero - ILLENIUM Remix'
# Fetching lyrics for: Anti-Hero (feat. Bleachers)
# Lyrics found for 'Anti-Hero (feat. Bleachers)'
# Fetching lyrics for: Anti-Hero - Roosevelt Remix
# Lyrics found for 'Anti-Hero - Roosevelt Remix'
# Fetching lyrics for: Anti-Hero - Kungs Remix
# Lyrics found for 'Anti-Hero - Kungs Remix'
# Fetching lyrics for: Anti-Hero - Jayda G Remix
# Lyrics found for 'Anti-Hero - Jayda G Remix'
# Fetching lyrics for: Anti-Hero
# Lyrics found for 'Anti-Hero'
# Fetching lyrics for: Anti-Hero (feat. Bleachers)
# Lyrics found for 'Anti-Hero (feat. Bleachers)'
# Fetching lyrics for: Anti-Hero
# Lyrics found for 'Anti-Hero'
# Fetching lyrics for: Carolina - From The Motion Picture “Where The Crawdads Sing”
# No lyrics found for 'Carolina - From The Motion Picture “Where The Crawdads Sing”'
# Fetching lyrics for: Carolina - "Where The Crawdads Sing" - Video Edition
# No lyrics found for 'Carolina - "Where The Crawdads Sing" - Video Edition'
# Fetching lyrics for: All Too Well (10 Minute Version) (The Short Film)
# Lyrics found for 'All Too Well (10 Minute Version) (The Short Film)'
# Fetching lyrics for: This Love (Taylor’s Version)
# Lyrics found for 'This Love (Taylor’s Version)'
# Fetching lyrics for: Wildest Dreams (Taylor's Version)
# Lyrics found for 'Wildest Dreams (Taylor's Version)'
# Fetching lyrics for: The Joker And The Queen (feat. Taylor Swift)
# Lyrics found for 'The Joker And The Queen (feat. Taylor Swift)'
# Fetching lyrics for: Message In A Bottle (Fat Max G Remix) (Taylor’s Version)
# Lyrics found for 'Message In A Bottle (Fat Max G Remix) (Taylor’s Version)'
# Fetching lyrics for: Message In A Bottle (Taylor's Version) (From The Vault)
# Lyrics found for 'Message In A Bottle (Taylor's Version) (From The Vault)'
# Fetching lyrics for: Christmas Tree Farm (Old Timey Version)
# Lyrics found for 'Christmas Tree Farm (Old Timey Version)'
# Fetching lyrics for: All Too Well (Sad Girl Autumn Version) - Recorded at Long Pond Studios
# Lyrics found for 'All Too Well (Sad Girl Autumn Version) - Recorded at Long Pond Studios'
# Fetching lyrics for: I Knew You Were Trouble (Taylor's Version)
# Lyrics found for 'I Knew You Were Trouble (Taylor's Version)'
# Fetching lyrics for: 22 (Taylor's Version)
# Lyrics found for '22 (Taylor's Version)'
# Fetching lyrics for: We Are Never Ever Getting Back Together (Taylor's Version)
# Lyrics found for 'We Are Never Ever Getting Back Together (Taylor's Version)'
# Fetching lyrics for: All Too Well (10 Minute Version) (Taylor's Version) (From The Vault)
# Lyrics found for 'All Too Well (10 Minute Version) (Taylor's Version) (From The Vault)'
# Fetching lyrics for: Eyes Open (Taylor's Version)
# Lyrics found for 'Eyes Open (Taylor's Version)'
# Fetching lyrics for: Safe & Sound (feat. Joy Williams and John Paul White) (Taylor’s Version)
# Lyrics not available for 'Safe & Sound (feat. Joy Williams and John Paul White) (Taylor’s Version)'

# %% [markdown]
# ### Recommendations

# %%
# Load the dataset with lyrics, mood, and audio features
df = pd.read_csv('taylor_swift_tracks_dataset.csv')

# Preprocess: Replace NaN lyrics, mood with empty strings or defaults
df['lyrics'] = df['lyrics'].fillna('')
df['mood'] = df['mood'].fillna('neutral')  # Default mood

# Select audio features to include in similarity calculation
audio_features = ['valence', 'energy', 'danceability', 'acousticness', 'tempo']

# Normalize audio features (bring all features to a common scale)
scaler = MinMaxScaler()
df[audio_features] = scaler.fit_transform(df[audio_features])

# Lemmatizer to normalize words
lemmatizer = WordNetLemmatizer()

# Custom function to preprocess lyrics (tokenization + lemmatization)
def preprocess_lyrics(lyrics):
    # Tokenize the lyrics
    tokens = word_tokenize(lyrics)
    
    # Lemmatize each word
    lemmatized_tokens = [lemmatizer.lemmatize(token.lower()) for token in tokens if token.isalpha()]
    
    # Join lemmatized tokens back into a string
    return ' '.join(lemmatized_tokens)

# Apply preprocessing to the lyrics
df['processed_lyrics'] = df['lyrics'].apply(preprocess_lyrics)

# Initialize the TF-IDF Vectorizer for lyrics
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(df['processed_lyrics'])



# Initialize VADER sentiment intensity analyzer
sid = SentimentIntensityAnalyzer()

# Function to calculate sentiment score for each song
def get_sentiment(lyrics):
    if lyrics:  # Ensure there are lyrics to analyze
        sentiment = sid.polarity_scores(lyrics)
        return sentiment['compound']  # Return the compound sentiment score (-1 to +1)
    return 0  # Return neutral if no lyrics available

# Apply sentiment analysis to each song's lyrics and store the sentiment score
df['sentiment'] = df['lyrics'].apply(get_sentiment)

# Helper function to extract base title from the full title
def extract_base_title(title):
    base_title = title.lower().split('(')[0].strip()  # Get text before any parentheses
    return base_title

# Helper function to calculate mood similarity
def mood_similarity(mood1, mood2):
    return 1 if mood1 == mood2 else 0
    

# Function to recommend similar songs based on lyrics and sentiment
def recommend_songs_based_on_lyrics_and_sentiment(song_name, num_recommendations=5, mood_weight=0.3, audio_weight=0.4):

    # Find the index of the song in the dataframe
    try:
        idx = df[df['track_name'].str.lower() == song_name.lower()].index[0]
    except IndexError:
        print(f"Song '{song_name}' not found in the dataset.")
        return
    
    # Get the mood and audio features of the input song
    input_song_mood = df.iloc[idx]['mood']
    input_song_audio_features = df.iloc[idx][audio_features].values.reshape(1, -1)
    
    # Compute cosine similarity for lyrics
    cosine_similarities_lyrics = cosine_similarity(tfidf_matrix[idx], tfidf_matrix).flatten()
    
    # Compute cosine similarity for audio features
    cosine_similarities_audio = cosine_similarity(input_song_audio_features, df[audio_features]).flatten()

    # Extract sentiment of the input song
    input_song_sentiment = df.iloc[idx]['sentiment']
    
    # Extract the base title of the input song to exclude its versions
    base_title_input = extract_base_title(song_name)
    
    # Get indices of the top similar songs, excluding the input song and its versions
    similar_indices = cosine_similarities_lyrics.argsort()[::-1]
    
    # Filter out the input song's versions and duplicate base titles
    recommended_songs = []
    for i in similar_indices:
        if df.iloc[i]['track_name'].lower() == song_name.lower():
            continue  # Skip the input song itself
        
        base_title_recommendation = extract_base_title(df.iloc[i]['track_name'])
        
        # Exclude songs that have the same base title as the input song or previously recommended songs
        if base_title_recommendation != base_title_input and base_title_recommendation not in [extract_base_title(song['track_name']) for song, _ in recommended_songs]:
            # Calculate mood similarity
            mood_sim = mood_similarity(input_song_mood, df.iloc[i]['mood'])
            
            # Combine lyrics similarity, mood similarity, and audio similarity using weights
            combined_score = ((1 - mood_weight - audio_weight) * cosine_similarities_lyrics[i] +
                              mood_weight * mood_sim +
                              audio_weight * cosine_similarities_audio[i])
            sentiment_difference = np.abs(df.iloc[i]['sentiment'] - input_song_sentiment)
            
            # Only recommend songs with a similar sentiment (difference below a certain threshold)
            if sentiment_difference < 0.2: 
                recommended_songs.append((df.iloc[i], combined_score))
        
        # Stop when we have enough unique recommendations
        if len(recommended_songs) == num_recommendations:
            break
    
    # Sort the recommendations by combined score
    recommended_songs = sorted(recommended_songs, key=lambda x: x[1], reverse=True)
    
    # Print the top unique recommendations
    print(f"\nTop {num_recommendations} unique recommendations based on lyrics and sentiment for '{song_name}':\n")
    for song, score in recommended_songs:
        print(f"{song['track_name']} (Album: {song['album_name']}, Score: {score:.4f}, Mood: {song['mood']}, Sentiment: {song['sentiment']})")
        print("\n")
# Function to randomly pick a song from the dataset
def pick_random_song():
    random_index = random.randint(0, len(df) - 1)  # Pick a random index
    random_song = df.iloc[random_index]['track_name']
    print(f"\nRandomly picked song: {random_song}")
    return random_song

# %%
random_song = pick_random_song()
print(f"Mood of the song is {df[df['track_name'] == random_song]['mood'].values[0]}")
# Example: Recommend songs based on "Love Story"
recommend_songs_based_on_lyrics_and_sentiment(random_song, num_recommendations=5, mood_weight=0.5, audio_weight=0.5)
# Out:
# Randomly picked song: Sparks Fly
# Mood of the song is Energetic
#
# Top 5 unique recommendations based on lyrics and sentiment for 'Sparks Fly':
#
# Beautiful Eyes - Live From Clear Channel Stripped 2008 (Album: Live From Clear Channel Stripped 2008, Score: 0.9384, Mood: Energetic, Sentiment: 0.9582)
#
#
# Superman (Taylor’s Version) (Album: Speak Now (Taylor's Version), Score: 0.4940, Mood: Sad, Sentiment: 0.9953)
#
#
# I Can See You (Taylor’s Version) (From The Vault) (Album: Speak Now (Taylor's Version), Score: 0.4779, Mood: Happy, Sentiment: 0.928)
#
#
# I Did Something Bad (Album: reputation, Score: 0.4764, Mood: Sad, Sentiment: 0.9991)
#
#
# Invisible (Album: Taylor Swift, Score: 0.3581, Mood: Sad, Sentiment: 0.99)
